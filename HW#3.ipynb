# %% [markdown]
# # Challenge 7.1

# %% [markdown]
# # part a)

# %%
# %matplotlib inline
import numpy as np
from matplotlib import pyplot
import math

def solve(V):
    Vnew = V
    nx = V.shape[0]
    ny = V.shape[1]
    for y in range(1,ny_2):
        for x in range(1,nx_2):
                if(y!=((ny_2-ny_1)/2) and y!=((ny_2+ny_1)/2) and x!=((nx_2-nx_1)/2) and x!=((nx_2+nx_1)/2)):
                        Vnew[y,x] = 0.25*(V[y,x-1]+V[y,x+1]+V[y-1,x]+V[y+1,x])
    return Vnew
            
lx_1 = 0.05
ly_1 = 0.05
lx_2 = 0.25
ly_2 = 0.25
nx_1 = 20
ny_1 = 20
nx_2 = 100
ny_2 = 100
dx = lx_2/nx_2
dy = ly_2/ny_2
V = np.zeros(shape=(ny_2+1,nx_2+1))


# Initialize arbitrary values
for y in range(1,ny_2):
    for x in range(1,nx_2):
        if(y!=((ny_2-ny_1)/2) and y!=((ny_2+ny_1)/2) and x!=((nx_2-nx_1)/2) and x!=((nx_2+nx_1)/2)):
             V[y,x] = 10*((x*dx)**2+(y*dy)**2)

# Initialize boundary conditions
for y in range((ny_2-ny_1)/2,(ny_2+ny_1)/2+1):
    V[y,(nx_2-nx_1)/2] = 5.
    V[y,(nx_2+nx_1)/2] = 5.
    
for x in range((nx_2-nx_1)/2,(nx_2+nx_1)/2+1):
    V[(ny_2-ny_1)/2,x] = 5.
    V[(ny_2+ny_1)/2,x] = 5.
    
for y in range(0,ny_2+1):
    V[y,0] = 10.
    V[y,nx_2] = 10.

for x in range(0,nx_2+1):
    V[0,x] = 10.
    V[ny_2,x] = 10.

for iter in range(1000):
     V = solve(V)   
    
x = np.arange(0, lx_2+dx, dx)
y = np.arange(0, ly_2+dy, dy)
X, Y = np.meshgrid(x, y)


CS = pyplot.contour(X, Y, V)
pyplot.clabel(CS, inline=1, fontsize=10);
print (ny_2-ny_1)/2+1
# Out:
# 41

# %%
pyplot.pcolormesh(X,Y,V);

# %% [markdown]
# # If I set the whole inner square to be 5, which means the inner square is conductor, we get the following result!

# %%
# %matplotlib inline
import numpy as np
from matplotlib import pyplot
import math

def solve(V):
    Vnew = V
    nx = V.shape[0]
    ny = V.shape[1]
    for y in range(1,ny_2):
        for x in range(1,nx_2):
                if(y>=((ny_2-ny_1)/2+1) and y<=((ny_2+ny_1)/2+1) and x>=((nx_2-nx_1)/2+1) and x<=((nx_2+nx_1)/2)+1):
                     V[y,x] = 5.
                else:
                        Vnew[y,x] = 0.25*(V[y,x-1]+V[y,x+1]+V[y-1,x]+V[y+1,x])
    return Vnew
            
lx_1 = 0.05
ly_1 = 0.05
lx_2 = 0.25
ly_2 = 0.25
nx_1 = 20
ny_1 = 20
nx_2 = 100
ny_2 = 100
dx = lx_2/nx_2
dy = ly_2/ny_2
V = np.zeros(shape=(ny_2+1,nx_2+1))


# Initialize arbitrary values
for y in range(1,ny_2):
    for x in range(1,nx_2):
        if(y>=((ny_2-ny_1)/2+1) and y<=((ny_2+ny_1)/2+1) and x>=((nx_2-nx_1)/2+1) and x<=((nx_2+nx_1)/2)+1):
            V[y,x] = 5.
        else:
             V[y,x] = 10*((x*dx)**2+(y*dy)**2)

# Initialize boundary conditions    
for y in range(0,ny_2+1):
    V[y,0] = 10.
    V[y,nx_2] = 10.

for x in range(0,nx_2+1):
    V[0,x] = 10.
    V[ny_2,x] = 10.

for iter in range(1000):
     V = solve(V)   
    
x = np.arange(0, lx_2+dx, dx)
y = np.arange(0, ly_2+dy, dy)
X, Y = np.meshgrid(x, y)


CS = pyplot.contour(X, Y, V)
pyplot.clabel(CS, inline=1, fontsize=10);
print (ny_2-ny_1)/2+1
# Out:
# 41

# %%
pyplot.pcolormesh(X,Y,V);

# %% [markdown]
# # part 3)

# %% [markdown]
# # I move the inner square 1cm left from the center, we can see that the potential also moves 1cm left from the previous one! Here only the boundary of the inner square is 5.

# %%
# %matplotlib inline
import numpy as np
from matplotlib import pyplot
import math

def solve(V):
    Vnew = V
    nx = V.shape[0]
    ny = V.shape[1]
    for y in range(1,ny_2):
        for x in range(1,nx_2):
            if(y!=((ny_2-ny_1)/2+1) and y!=((ny_2+ny_1)/2+1)):
                 if(x!=(nx_2/2-int(3.5*nx_1/5)+1) and x!=(nx_2/2+int(1.5*nx_1/5)+1)):
                        Vnew[y,x] = 0.25*(V[y,x-1]+V[y,x+1]+V[y-1,x]+V[y+1,x])
    return Vnew

lx_1 = 0.05
ly_1 = 0.05
lx_2 = 0.25
ly_2 = 0.25
nx_1 = 50
ny_1 = 50
nx_2 = 250
ny_2 = 250
dx = lx_2/nx_2
dy = ly_2/ny_2
V = np.zeros(shape=(ny_2+1,nx_2+1))


# Initialize arbitrary values
for y in range(1,ny_2):
    for x in range(1,nx_2):
        V[y,x] = 10*((x*dx)**2+(y*dy)**2)

# Initialize boundary conditions
for y in range((ny_2-ny_1)/2+1,(ny_2+ny_1)/2+1):
    V[y,nx_2/2-int(3.5*nx_1/5)+1] = 5.
    V[y,nx_2/2+int(1.5*nx_1/5)+1] = 5.
for x in range(nx_2/2-int(3.5*nx_1/5)+1,nx_2/2+int(1.5*nx_1/5)+1): #Move the inner square 1cm off center
    V[(ny_2-ny_1)/2+1,x] = 5.
    V[(ny_2+ny_1)/2+1,x] = 5.
for y in range(0,ny_2+1):
    V[y,0] = 10.
    V[y,nx_2] = 10.

for x in range(0,nx_2+1):
    V[0,x] = 10.
    V[ny_2,x] = 10.

    
for iter in range(1000):
    V = solve(V)
    
x = np.arange(0, lx_2+dx, dx)
y = np.arange(0, ly_2+dy, dy)
X, Y = np.meshgrid(x, y)


CS = pyplot.contour(X, Y, V)
pyplot.clabel(CS, inline=1, fontsize=10);
print nx_2/2-int(3.5*nx_1/5)+1
# Out:
# 91

# %%
pyplot.pcolormesh(X,Y,V);

# %% [markdown]
# # I move the inner square 1cm left from the center, we can see that the potential also moves 1cm left from the previous one! Set the whole inner square to be 5.

# %%
# %matplotlib inline
import numpy as np
from matplotlib import pyplot
import math

def solve(V):
    Vnew = V
    nx = V.shape[0]
    ny = V.shape[1]
    for y in range(1,ny_2):
        for x in range(1,nx_2):
            if(y>=((ny_2-ny_1)/2+1) and y<=((ny_2+ny_1)/2+1) and x>=(nx_2/2-int(3.5*nx_1/5)+1) and x<=(nx_2/2+int(1.5*nx_1/5)+1)):
                    Vnew[y,x] = 5.
            else:
                    Vnew[y,x] = 0.25*(V[y,x-1]+V[y,x+1]+V[y-1,x]+V[y+1,x])
    return Vnew

lx_1 = 0.05
ly_1 = 0.05
lx_2 = 0.25
ly_2 = 0.25
nx_1 = 50
ny_1 = 50
nx_2 = 250
ny_2 = 250
dx = lx_2/nx_2
dy = ly_2/ny_2
V = np.zeros(shape=(ny_2+1,nx_2+1))


# Initialize arbitrary values
for y in range(1,ny_2):
    for x in range(1,nx_2):
        if(y>=((ny_2-ny_1)/2+1) and y<=((ny_2+ny_1)/2+1) and x>=(nx_2/2-int(3.5*nx_1/5)+1) and x<=(nx_2/2+int(1.5*nx_1/5)+1)):
             V[y,x] = 5.
        else:
             V[y,x] = 10*((x*dx)**2+(y*dy)**2)

# Initialize boundary conditions
for y in range(0,ny_2+1):
    V[y,0] = 10.
    V[y,nx_2] = 10.

for x in range(0,nx_2+1):
    V[0,x] = 10.
    V[ny_2,x] = 10.

    
for iter in range(1000):
    V = solve(V)
    
x = np.arange(0, lx_2+dx, dx)
y = np.arange(0, ly_2+dy, dy)
X, Y = np.meshgrid(x, y)


CS = pyplot.contour(X, Y, V)
pyplot.clabel(CS, inline=1, fontsize=10);
print nx_2/2-int(3.5*nx_1/5)+1
# Out:
# 91

# %%
pyplot.pcolormesh(X,Y,V);

# %% [markdown]
# # Set the inner conductor to be -5 !

# %%
# %matplotlib inline
import numpy as np
from matplotlib import pyplot
import math

def solve(V):
    Vnew = V
    nx = V.shape[0]
    ny = V.shape[1]
    for y in range(1,ny_2):
        for x in range(1,nx_2):
                if(y>=((ny_2-ny_1)/2+1) and y<=((ny_2+ny_1)/2+1) and x>=((nx_2-nx_1)/2+1) and x<=((nx_2+nx_1)/2)+1):
                     V[y,x] = -5.
                else:
                        Vnew[y,x] = 0.25*(V[y,x-1]+V[y,x+1]+V[y-1,x]+V[y+1,x])
    return Vnew
            
lx_1 = 0.05
ly_1 = 0.05
lx_2 = 0.25
ly_2 = 0.25
nx_1 = 20
ny_1 = 20
nx_2 = 100
ny_2 = 100
dx = lx_2/nx_2
dy = ly_2/ny_2
V = np.zeros(shape=(ny_2+1,nx_2+1))


# Initialize arbitrary values
for y in range(1,ny_2):
    for x in range(1,nx_2):
        if(y>=((ny_2-ny_1)/2+1) and y<=((ny_2+ny_1)/2+1) and x>=((nx_2-nx_1)/2+1) and x<=((nx_2+nx_1)/2)+1):
            V[y,x] = -5.
        else:
             V[y,x] = 10*((x*dx)**2+(y*dy)**2)

# Initialize boundary conditions
for y in range(0,ny_2+1):
    V[y,0] = 10.
    V[y,nx_2] = 10.

for x in range(0,nx_2+1):
    V[0,x] = 10.
    V[ny_2,x] = 10.

for iter in range(1000):
     V = solve(V)   
    
x = np.arange(0, lx_2+dx, dx)
y = np.arange(0, ly_2+dy, dy)
X, Y = np.meshgrid(x, y)


CS = pyplot.contour(X, Y, V)
pyplot.clabel(CS, inline=1, fontsize=10);
print (ny_2-ny_1)/2+1
# Out:
# 41

# %%
pyplot.pcolormesh(X,Y,V);

# %% [markdown]
# # Challenge 7.2

# %%
# %matplotlib inline
import numpy as np
from matplotlib import pyplot
import math

def solve(V):
    Vnew = V
    nx = V.shape[0]
    ny = V.shape[1]
    for y in range(1,ny-1):
        for x in range(1,nx-1):
                Vnew[y,x] = 0.5*((V[y,x-1]+V[y,x+1])*dy**2+(V[y-1,x]+V[y+1,x])*dx**2+12*(dx*dy)**2)/(dx**2+dy**2)
    return Vnew
            
lx = 0.25
ly = 0.25
nx = 100
ny = 100
dx = lx/nx
dy = ly/ny
V = np.zeros(shape=(ny+1,nx+1))


# Initialize arbitrary values
for y in range(1,ny):
    for x in range(1,nx):
        V[y,x] = 10*((x*dx)**2+(y*dy)**2)

# Initialize boundary conditions
for y in range(0,ny+1):
    V[y,0] = 10.
    V[y,nx] = 10.

for x in range(0,nx+1):
    V[0,x] = 10.
    V[ny,x] = 10.
    
for iter in range(1000):
    V = solve(V)
    
x = np.arange(0, lx+dx, dx)
y = np.arange(0, ly+dy, dy)
X, Y = np.meshgrid(x, y)


CS = pyplot.contour(X, Y, V)
pyplot.clabel(CS, inline=1, fontsize=10);

# %%
pyplot.pcolormesh(X,Y,V);

# %%
# %matplotlib inline
import numpy as np
from matplotlib import pyplot
import math

def solve(V):
    Vnew = V
    nx = V.shape[0]
    ny = V.shape[1]
    for y in range(1, ny_2-1):
        for x in range(1, nx_2-1):
                if(x>(nx_2-nx_1)/2+1) and x <((nx_2+nx_1)/2+1) and y>((ny_2-ny_1)/2+1) and y <((ny_2+ny_1)/2+1):
                    Vnew[y,x] = 0.5*((V[y,x-1]+V[y,x+1])*dy**2+(V[y-1,x]+V[y+1,x])*dx**2+12*(dx*dy)**2)/(dx**2+dy**2)
                else:
                    Vnew[y,x] = 0.25*(V[y,x-1]+V[y,x+1]+V[y-1,x]+V[y+1,x])
    return Vnew
            
lx_1 = 0.05
ly_1 = 0.05
lx_2 = 0.25
ly_2 = 0.25
nx_1 = 20
ny_1 = 20
nx_2 = 100
ny_2 = 100
dx = lx_2/nx_2
dy = ly_2/ny_2
V = np.zeros(shape=(ny_2+1,nx_2+1))


# Initialize arbitrary values
for y in range(1,ny_2):
    for x in range(1,nx_2):
        V[y,x] = 10
        #V[y,x] = 10*((x*dx)**2+(y*dy)**2)

# Initialize boundary conditions
for y in range(0,ny_2+1):
    V[y,0] = 10.
    V[y,nx_2] = 10.

for x in range(0,nx_2+1):
    V[0,x] = 10.
    V[ny_2,x] = 10.
    
for iter in range(1000):
    V = solve(V)
    
x = np.arange(0, lx_2+dx, dx)
y = np.arange(0, ly_2+dy, dy)
X, Y = np.meshgrid(x, y)


CS = pyplot.contour(X, Y, V)
pyplot.clabel(CS, inline=1, fontsize=10);
print (ny_2-ny_1)/2+1
# Out:
# 41

# %% [markdown]
# # The charge distribution of part 1) is restricted to a square of side  L=5cm in the center.

# %%
pyplot.pcolormesh(X,Y,V);
